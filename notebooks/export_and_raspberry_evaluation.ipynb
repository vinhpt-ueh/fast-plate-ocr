# %%
from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("best.pt")

# Export to NCNN format
model.export(format="ncnn")  # creates '/yolo11n_ncnn_model'
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/vinh/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.103 🚀 Python-3.11.2 torch-2.6.0+cpu CPU (Cortex-A76)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 1024, 1024) BCHW and output shape(s) (1, 5, 21504) (5.2 MB)
#
# TorchScript: starting export with torch 2.6.0+cpu...
# TorchScript: export success ✅ 10.7s, saved as 'best.torchscript' (10.5 MB)
# requirements: Ultralytics requirement ['ncnn'] not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://www.piwheels.org/simple
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 2.6 MB/s eta 0:00:002.5 MB/s eta 0:00:01
# ...
#
# ...

# %%
from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("best.pt")

# Export to NCNN format
model.export(format="ncnn",imgsz=(1024,576))  # creates '/yolo11n_ncnn_model'
# Out:
# Ultralytics 8.3.103 🚀 Python-3.11.2 torch-2.6.0+cpu CPU (Cortex-A76)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 1024, 576) BCHW and output shape(s) (1, 5, 12096) (5.2 MB)
#
# TorchScript: starting export with torch 2.6.0+cpu...
# TorchScript: export success ✅ 6.6s, saved as 'best.torchscript' (10.5 MB)
#
# NCNN: starting export with NCNN 1.0.20241226...
# NCNN: running '/home/vinh/myenv/lib/python3.11/site-packages/ultralytics/pnnx best.torchscript ncnnparam=best_ncnn_model/model.ncnn.param ncnnbin=best_ncnn_model/model.ncnn.bin ncnnpy=best_ncnn_model/model_ncnn.py pnnxparam=best_ncnn_model/model.pnnx.param pnnxbin=best_ncnn_model/model.pnnx.bin pnnxpy=best_ncnn_model/model_pnnx.py pnnxonnx=best_ncnn_model/model.pnnx.onnx fp16=0 device=cpu inputshape="[1, 3, 1024, 576]"'
# pnnxparam = best_ncnn_model/model.pnnx.param
# pnnxbin = best_ncnn_model/model.pnnx.bin
# ...

# %%
# Load the exported NCNN model
ncnn_model = YOLO("best_ncnn_model")
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.

# %%
results = ncnn_model("/home/vinh/Development/test/images/track0091_01.png")
results
# Out:
# image 1/1 /home/vinh/Development/test/images/track0091_01.png: 640x640 300 License_Plates, 504.6ms
# Speed: 17.5ms preprocess, 504.6ms inference, 269.9ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'License_Plate'}
#  obb: None
#  orig_img: array([[[218, 206, 198],
#          [218, 206, 198],
#          [221, 209, 203],
#          ...,
#          [255, 254, 255],
#          [255, 254, 255],
#          [255, 254, 255]],
#
#         [[236, 224, 216],
#          [229, 217, 209],
#          [219, 207, 201],
#          ...,
#          [255, 254, 255],
#          [255, 254, 255],
#          [255, 254, 255]],
#
#         [[246, 233, 227],
#          [246, 233, 227],
#          [247, 234, 228],
#          ...,
#          [255, 254, 255],
#          [255, 254, 255],
#          [255, 254, 255]],
#
#         ...,
#
# ...

# %%
# !yolo predict model='best_ncnn_model' source='/home/vinh/Development/test/images/track0092_01.png' imgsz=1024,576 rect
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.103 🚀 Python-3.11.2 torch-2.6.0+cpu CPU (Cortex-A76)
# Loading best_ncnn_model for NCNN inference...
#
# image 1/1 /home/vinh/Development/test/images/track0092_01.png: 1024x576 1 License_Plate, 251.0ms
# Speed: 14.9ms preprocess, 251.0ms inference, 4.4ms postprocess per image at shape (1, 3, 1024, 576)
# Results saved to runs/detect/predict10
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model='best.pt' source='/home/vinh/Development/test/images/track0092_01.png' imgsz=1024 rect
# Out:
# Ultralytics 8.3.103 🚀 Python-3.11.2 torch-2.6.0+cpu CPU (Cortex-A76)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /home/vinh/Development/test/images/track0092_01.png: 576x1024 1 License_Plate, 946.2ms
# Speed: 18.5ms preprocess, 946.2ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 1024)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model='best_openvino_model_fp' source='/home/vinh/Development/test/images/track0092_01.png' imgsz=1024
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.103 🚀 Python-3.11.2 torch-2.6.0+cpu CPU (Cortex-A76)
# Loading best_openvino_model_fp for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference...
#
# image 1/1 /home/vinh/Development/test/images/track0092_01.png: 1024x1024 1 License_Plate, 338.3ms
# Speed: 30.1ms preprocess, 338.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to runs/detect/predict12
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model='best_int8_openvino_model' source='/home/vinh/Development/test/images/track0092_01.png' imgsz=1024
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.103 🚀 Python-3.11.2 torch-2.6.0+cpu CPU (Cortex-A76)
# Loading best_int8_openvino_model for OpenVINO inference...
# Using OpenVINO LATENCY mode for batch=1 inference...
#
# image 1/1 /home/vinh/Development/test/images/track0092_01.png: 576x1024 1 License_Plate, 863.7ms
# Speed: 21.5ms preprocess, 863.7ms inference, 3.5ms postprocess per image at shape (1, 3, 576, 1024)
# Results saved to runs/detect/predict15
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model='best_no_dynamic.onnx' source='/home/vinh/Development/test/images/track0092_01.png' imgsz=1024
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.103 🚀 Python-3.11.2 torch-2.6.0+cpu CPU (Cortex-A76)
# Loading best_no_dynamic.onnx for ONNX Runtime inference...
# Using ONNX Runtime CPUExecutionProvider
#
# image 1/1 /home/vinh/Development/test/images/track0092_01.png: 1024x1024 1 License_Plate, 994.7ms
# Speed: 35.0ms preprocess, 994.7ms inference, 8.8ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Export the model to ONNX format
model.export(format="onnx")  # creates 'yolo11n.onnx'
# Out:
# Ultralytics 8.3.82  Python-3.9.20 torch-1.8.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 1024, 1024) BCHW and output shape(s) (1, 5, 21504) (5.2 MB)
# requirements: Ultralytics requirement ['onnxslim'] not found, attempting AutoUpdate...
# Retry 1/2 failed: Command 'pip install --no-cache-dir "onnxslim" ' returned non-zero exit status 1.
# Retry 2/2 failed: Command 'pip install --no-cache-dir "onnxslim" ' returned non-zero exit status 1.
# requirements:  Command 'pip install --no-cache-dir "onnxslim" ' returned non-zero exit status 1.
#
# ONNX: starting export with onnx 1.12.0 opset 12...
# ONNX: simplifier failure: No module named 'onnxslim'
# ONNX: export success  5.9s, saved as 'best.onnx' (10.3 MB)
#
# Export complete (8.6s)
# Results saved to C:\Users\Vinh\Downloads\kaggle\working\runs\detect\train\weights
# ...
